# %% [markdown]
# # Plantvillage Dataset Analysis
#
# This notebook provides a breakdown and visualization of the **plantvillage** dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
import random

# Setup plotting style
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Configuration
DATASET_NAME = "plantvillage"
PROCESSED_DIR = "PlantVillage_processed"
# Path relative to this notebook (notebooks/datasets/)
DATA_ROOT = Path("../../data/processed/dataset")
CSV_PATH = DATA_ROOT / PROCESSED_DIR / "labels.csv"

# %%
# Load the dataset metadata
if not CSV_PATH.exists():
    print(f"Error: Labels file not found at {CSV_PATH}")
else:
    df = pd.read_csv(CSV_PATH)
    print(f"Successfully loaded {len(df)} records.")
    display(df.head())
# Out:
# Successfully loaded 41276 records.
#           filename                       label    crop              disease  \
# 0  image-00001.jpg  pepper_bell_bacterial_spot  pepper  bell_bacterial_spot
# 1  image-00002.jpg  pepper_bell_bacterial_spot  pepper  bell_bacterial_spot
# 2  image-00003.jpg  pepper_bell_bacterial_spot  pepper  bell_bacterial_spot
# 3  image-00004.jpg  pepper_bell_bacterial_spot  pepper  bell_bacterial_spot
# 4  image-00005.jpg  pepper_bell_bacterial_spot  pepper  bell_bacterial_spot
#
#                  original_folder  \
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot
#
#                                                 path
# 0  PlantVillage_processed/pepper_bell_bacterial_s...
# 1  PlantVillage_processed/pepper_bell_bacterial_s...
# 2  PlantVillage_processed/pepper_bell_bacterial_s...
# 3  PlantVillage_processed/pepper_bell_bacterial_s...
# 4  PlantVillage_processed/pepper_bell_bacterial_s...

# %% [markdown]
# ## 1. Class Distribution
# Let's look at how the images are distributed across different classes.

# %%
if 'df' in locals():
    class_counts = df['label'].value_counts()
    print(f"Total Classes: {len(class_counts)}")
    
    # Plot
    plt.figure(figsize=(15, 8))
    class_counts.plot(kind='bar')
    plt.title(f"{DATASET_NAME} - Class Distribution")
    plt.xlabel("Class Label")
    plt.ylabel("Number of Images")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
    
    display(class_counts.to_frame(name='Count'))
# Out:
# Total Classes: 15
#                                              Count
# label
# tomato_yellow_curl_virus                      6416
# tomato_bacterial_spot                         4254
# tomato_late_blight                            3818
# tomato_septoria_spot                          3542
# tomato_spider_mites_two_spotted_spider_mite   3352
# tomato_healthy                                3182
# pepper_bell_healthy                           2956
# tomato_target_spot                            2808
# potato_early_blight                           2000
# potato_late_blight                            2000
# tomato_early_blight                           2000
# pepper_bell_bacterial_spot                    1994
# tomato_mold                                   1904
# tomato_mosaic_virus                            746
# potato_healthy                                 304

# %% [markdown]
# ## 2. Crop Analysis
# Breakdown by crop type (extracted from labels).

# %%
if 'df' in locals() and 'crop' in df.columns:
    crop_counts = df['crop'].value_counts()
    
    plt.figure(figsize=(10, 6))
    crop_counts.plot(kind='bar', color='green')
    plt.title(f"{DATASET_NAME} - Crop Distribution")
    plt.ylabel("Count")
    plt.show()
    display(crop_counts.to_frame(name='Count'))
# Out:
#         Count
# crop
# tomato  32022
# pepper   4950
# potato   4304

# %% [markdown]
# ## 3. Sample Images
# Displaying random samples from the dataset to verify quality and content.

# %%
def show_random_samples(df, n=9):
    if df is None or len(df) == 0: return
    
    plt.figure(figsize=(15, 15))
    samples = df.sample(min(n, len(df)))
    
    for i, (_, row) in enumerate(samples.iterrows()):
        plt.subplot(3, 3, i+1)
        # The 'path' column in csv is relative to data/processed/dataset
        img_path = DATA_ROOT / row['path']
        
        try:
            img = Image.open(img_path)
            plt.imshow(img)
            plt.title(f"{row['label']}\n({row['crop']})", fontsize=10)
            plt.axis('off')
        except Exception as e:
            plt.text(0.5, 0.5, f"Error loading image:\n{str(e)}", ha='center')
            plt.axis('off')
            
    plt.tight_layout()
    plt.show()

if 'df' in locals():
    show_random_samples(df)
